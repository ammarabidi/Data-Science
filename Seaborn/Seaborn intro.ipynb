# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="dark")

# %%
x = np.array([1, 2, 3, 4, 5,6,767,7,8,8,4,34,3,43,43,43,78,89,90])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
